# %%
import pandas as pd
import re

from datetime import datetime
import os
import deltalake
from deltalake import DeltaTable
from deltalake.writer import write_deltalake
import duckdb
current_folder_path = os.path.abspath('.')

# %%
current_folder_path+ '\\data\\as_of\\'
# Out:
# '/Users/amuhammadzuharimi/personal_projects/data-gov-my-railway\\data\\as_of\\'

# %%
def load_railway() -> pd.DataFrame:
    filters = [("frequency", "==", "daily")
            ]
    df = pd.read_parquet('https://storage.data.gov.my/dashboards/prasarana_timeseries.parquet', filters=filters)
    
    df['date'] = pd.to_datetime(df['date'], format="%Y-%B-%d")
    df['year'] = df['date'].dt.year
    df['month'] = df['date'].dt.month
    df['day'] = df['date'].dt.day
    df['day_name'] = df['date'].dt.day_name()

    df['station_code_origin'] = [re.search(r'(\w+):', x).group(1) for x in df['origin']]
    df['station_code_destination'] = [re.search(r'(\w+):', x).group(1) for x in df['destination']]
    df['station_name_origin'] = [re.search(r':\s*([\w\s]+)', x).group(1) + ' (origin)' for x in df['origin']]
    df['station_name_destination'] = [re.search(r':\s*([\w\s]+)', x).group(1) + ' (destination)' for x in df['destination']]

    df['line_origin'] = [re.search(r'(\D+)\d+',x).group(1) for x in df['station_code_origin']]
    df['line_destination'] = [re.search(r'(\D+)\d+',x).group(1) for x in df['station_code_destination']]

    df = df.loc[(df.line_origin != 'A') & (df.line_destination != 'A')].reset_index(drop=True)

    line_mapper_dict = {'A':'All Station', 
                        'AG':'LRT Ampang Line', 
                        'BRT':'Bus Rapid Transit', 
                        'KG':'MRT Kajang Line', 
                        'KJ':'LRT Kajang Line', 
                        'MR':'Monorail', 
                        'PYL':'MRT Putrajaya Line', 
                        'SP':'LRT Sri Petaling Line'}

    df['line_name_origin'] = df['line_origin'].map(line_mapper_dict)
    df['line_name_destination'] = df['line_destination'].map(line_mapper_dict)

    str_cols = [x for x in df.columns if x not in ('date', 'passengers')]
    df[str_cols]= df[str_cols].astype('string')
    print(f"Data contains {df.shape[0]} rows")
    return df

# %%
df = load_railway()
# write_deltalake(current_folder_path + '\\data\\ridership\\', df, mode='overwrite')
df.to_parquet('./data/railway/ridership/passengers_daily.parquet')
# Out:
# Data contains 1038597 rows

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1038597 entries, 0 to 1038596
# Data columns (total 18 columns):
#  #   Column                    Non-Null Count    Dtype
# ---  ------                    --------------    -----
#  0   service                   1038597 non-null  string
#  1   frequency                 1038597 non-null  string
#  2   origin                    1038597 non-null  string
#  3   destination               1038597 non-null  string
#  4   date                      1038597 non-null  datetime64[ns]
#  5   passengers                1038597 non-null  int64
#  6   year                      1038597 non-null  string
#  7   month                     1038597 non-null  string
#  8   day                       1038597 non-null  string
#  9   day_name                  1038597 non-null  string
#  10  station_code_origin       1038597 non-null  string
#  11  station_code_destination  1038597 non-null  string
#  12  station_name_origin       1038597 non-null  string
#  13  station_name_destination  1038597 non-null  string
#  14  line_origin               1038597 non-null  string
#  15  line_destination          1038597 non-null  string
#  16  line_name_origin          1038597 non-null  string
#  17  line_name_destination     1038597 non-null  string
# dtypes: datetime64[ns](1), int64(1), string(16)
# memory usage: 142.6 MB

# %%
def store_load_date(df:pd.DataFrame):
    data_as_of = df.date.max().date().isoformat()
    df_data_as_of = pd.DataFrame({'load_date':[data_as_of]})
    print('Data as of:',data_as_of)
    try: 
        pd.read_parquet("./data/as_of/").load_date.max()
        if pd.read_parquet("./data/as_of/").load_date.max() <= data_as_of:
            pass
        else:
            write_deltalake(current_folder_path + '\\data\\as_of\\', df_data_as_of, mode='append')
    except:
        write_deltalake(current_folder_path + '\\data\\as_of\\', df_data_as_of, mode='append')

store_load_date(df)
# Out:
# Data as of: 2024-07-27

# %%
df.sample(10)
# Out:
#         service frequency                      origin  \
# 527195     rail     daily         KJ25: Lembah Subang
# 208324     rail     daily                  KG10: TTDI
# 542883     rail     daily         KJ27: Cgc Glenmarie
# 163507     rail     daily       KG04: Kwasa Damansara
# 174564     rail     daily         KG05: Kwasa Sentral
# 641879     rail     daily         MR06: Bukit Bintang
# 941160     rail     daily  SP15: Bandar Tasik Selatan
# 484909     rail     daily              KJ18: Kerinchi
# 1011973    rail     daily         SP27: Bandar Puteri
# 759933     rail     daily             PYL14: Kentomen
#
#                      destination       date  passengers  year month day  \
# 527195   BRT06: South Quay-USJ 1 2024-06-03           1  2024     6   3
# 208324          KJ14: Pasar Seni 2024-07-17         152  2024     7  17
# 542883               KJ08: Damai 2024-06-16           2  2024     6  16
# 163507        AG01: Sentul Timur 2024-07-02           6  2024     7   2
# 174564     KJ22: Taman Paramount 2024-07-01           3  2024     7   1
# 641879          AG03: Titiwangsa 2024-06-03          47  2024     6   3
# 941160         MR07: Raja Chulan 2024-07-04          58  2024     7   4
# 484909       SP31: Putra Heights 2024-06-11         114  2024     6  11
# 1011973             AG18: Ampang 2024-07-23          16  2024     7  23
# 759933          KG16: Pasar Seni 2024-06-10           7  2024     6  10
#
#           day_name station_code_origin station_code_destination  \
# 527195      Monday                KJ25                    BRT06
# 208324   Wednesday                KG10                     KJ14
# 542883      Sunday                KJ27                     KJ08
# 163507     Tuesday                KG04                     AG01
# 174564      Monday                KG05                     KJ22
# 641879      Monday                MR06                     AG03
# 941160    Thursday                SP15                     MR07
# 484909     Tuesday                KJ18                     SP31
# 1011973    Tuesday                SP27                     AG18
# 759933      Monday               PYL14                     KG16
#
#                    station_name_origin       station_name_destination  \
# 527195          Lembah Subang (origin)       South Quay (destination)
# 208324                   TTDI (origin)       Pasar Seni (destination)
# 542883          Cgc Glenmarie (origin)            Damai (destination)
# 163507        Kwasa Damansara (origin)     Sentul Timur (destination)
# 174564          Kwasa Sentral (origin)  Taman Paramount (destination)
# 641879          Bukit Bintang (origin)       Titiwangsa (destination)
# 941160   Bandar Tasik Selatan (origin)      Raja Chulan (destination)
# 484909               Kerinchi (origin)    Putra Heights (destination)
# 1011973         Bandar Puteri (origin)           Ampang (destination)
# 759933               Kentomen (origin)       Pasar Seni (destination)
#
#         line_origin line_destination       line_name_origin  \
# 527195           KJ              BRT        LRT Kajang Line
# 208324           KG               KJ        MRT Kajang Line
# 542883           KJ               KJ        LRT Kajang Line
# 163507           KG               AG        MRT Kajang Line
# 174564           KG               KJ        MRT Kajang Line
# 641879           MR               AG               Monorail
# 941160           SP               MR  LRT Sri Petaling Line
# 484909           KJ               SP        LRT Kajang Line
# 1011973          SP               AG  LRT Sri Petaling Line
# 759933          PYL               KG     MRT Putrajaya Line
#
#          line_name_destination
# 527195       Bus Rapid Transit
# 208324         LRT Kajang Line
# 542883         LRT Kajang Line
# 163507         LRT Ampang Line
# 174564         LRT Kajang Line
# 641879         LRT Ampang Line
# 941160                Monorail
# 484909   LRT Sri Petaling Line
# 1011973        LRT Ampang Line
# 759933         MRT Kajang Line

# %% [markdown]
# ## Grouping

# %%
df_grouped = df.groupby(['origin',
            'line_origin',
            'line_name_origin',
            'date',
            'year',
            'month',
            'day',
            'day_name',]).agg({'passengers':'sum'}).reset_index()

# %%
df_grouped.sample(10)
# Out:
#                      origin line_origin    line_name_origin       date  year  \
# 2614     KG27: Taman Suntex          KG     MRT Kajang Line 2024-07-20  2024
# 4114       KJ20: Taman Jaya          KJ     LRT Kajang Line 2024-06-11  2024
# 3359          KJ06: Jelatek          KJ     LRT Kajang Line 2024-07-24  2024
# 4602      KJ28: Subang Jaya          KJ     LRT Kajang Line 2024-07-13  2024
# 5623         MR10: Chow Kit          MR            Monorail 2024-07-08  2024
# 5794    PYL04: Sungai Buloh         PYL  MRT Putrajaya Line 2024-07-08  2024
# 6728  PYL21: Persiaran KLCC         PYL  MRT Putrajaya Line 2024-06-03  2024
# 3449            KJ08: Damai          KJ     LRT Kajang Line 2024-06-30  2024
# 6864    PYL24: Chan Sow Lin         PYL  MRT Putrajaya Line 2024-06-25  2024
# 2519  KG26: Taman Connaught          KG     MRT Kajang Line 2024-06-12  2024
#
#      month day   day_name  passengers
# 2614     7  20   Saturday        2866
# 4114     6  11    Tuesday        4823
# 3359     7  24  Wednesday        3737
# 4602     7  13   Saturday        2860
# 5623     7   8     Monday        4094
# 5794     7   8     Monday        2206
# 6728     6   3     Monday         765
# 3449     6  30     Sunday        1313
# 6864     6  25    Tuesday        1048
# 2519     6  12  Wednesday        5874

# %%
df_grouped.to_parquet('./data/railway/ridership/daily/passengers_by_station.parquet', )

# %% [markdown]
# # Test

# %% [markdown]
# df

# %%
fname = [x.date().isoformat() for x in df_grouped['date'].unique()]
fname
# Out:
# ['2024-06-01',
#  '2024-06-02',
#  '2024-06-03',
#  '2024-06-04',
#  '2024-06-05',
#  '2024-06-06',
#  '2024-06-07',
#  '2024-06-08',
#  '2024-06-09',
#  '2024-06-10',
#  '2024-06-11',
#  '2024-06-12',
#  '2024-06-13',
#  '2024-06-14',
#  '2024-06-15',
#  '2024-06-16',
#  '2024-06-17',
#  '2024-06-18',
#  '2024-06-19',
#  '2024-06-20',
#  '2024-06-21',
#  '2024-06-22',
#  '2024-06-23',
#  '2024-06-24',
#  '2024-06-25',
#  '2024-06-26',
#  '2024-06-27',
#  '2024-06-28',
#  '2024-06-29',
#  '2024-06-30',
#  '2024-07-01',
#  '2024-07-02',
#  '2024-07-03',
#  '2024-07-04',
#  '2024-07-05',
#  '2024-07-06',
#  '2024-07-07',
#  '2024-07-08',
#  '2024-07-09',
#  '2024-07-10',
#  '2024-07-11',
#  '2024-07-12',
#  '2024-07-13',
#  '2024-07-14',
#  '2024-07-15',
#  '2024-07-16',
#  '2024-07-17',
#  '2024-07-18',
#  '2024-07-19',
#  '2024-07-20',
#  '2024-07-21',
#  '2024-07-22',
#  '2024-07-23',
#  '2024-07-24',
#  '2024-07-25',
#  '2024-07-26',
#  '2024-07-27']

# %%
df_grouped['date'] = df_grouped['date'].astype('str')

# %%
df_grouped.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8664 entries, 0 to 8663
# Data columns (total 9 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   origin            8664 non-null   string
#  1   line_origin       8664 non-null   string
#  2   line_name_origin  8664 non-null   string
#  3   date              8664 non-null   object
#  4   year              8664 non-null   string
#  5   month             8664 non-null   string
#  6   day               8664 non-null   string
#  7   day_name          8664 non-null   string
#  8   passengers        8664 non-null   int64
# dtypes: int64(1), object(1), string(7)
# memory usage: 609.3+ KB

# %%
for t in fname:
    temp_ = df_grouped.loc[df_grouped['date'] == t].reset_index(drop=True)
    file_name = f'data/railway/daily_agg/ridership_{t}.parquet'
    temp_.to_parquet(file_name)
